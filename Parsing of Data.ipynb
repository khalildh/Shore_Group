# %%
import pandas
import random
import numpy

# %%
data = pandas.read_csv("loan/src/data/LoanStats3a.csv")
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (0,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'hardship_payoff_balance_amount', 'hardship_last_payment_amount',
#        'disbursement_method', 'debt_settlement_flag',
#        'debt_settlement_flag_date', 'settlement_status', 'settlement_date',
#        'settlement_amount', 'settlement_percentage', 'settlement_term'],
#       dtype='object', length=145)

# %%
loan = list(data['loan_amnt'])

# %%
data
# Out:
#                                                     id  member_id  loan_amnt  \
# 0                                                  NaN        NaN     5000.0
# 1                                                  NaN        NaN     2500.0
# 2                                                  NaN        NaN     2400.0
# 3                                                  NaN        NaN    10000.0
# 4                                                  NaN        NaN     3000.0
# 5                                                  NaN        NaN     5000.0
# 6                                                  NaN        NaN     7000.0
# 7                                                  NaN        NaN     3000.0
# 8                                                  NaN        NaN     5600.0
# 9                                                  NaN        NaN     5375.0
# 10                                                 NaN        NaN     6500.0
# ...

# %%
state = data['addr_state']
unq_state = data['addr_state'].unique()

# %%
state
# Out:
# 0         AZ
# 1         GA
# 2         IL
# 3         CA
# 4         OR
# 5         AZ
# 6         NC
# 7         CA
# 8         CA
# 9         TX
# 10        AZ
# 11        CA
# 12        VA
# 13        IL
# 14        CA
# 15        MO
# 16        CA
# 17        CT
# 18        UT
# 19        CA
# 20        TX
# 21        FL
# 22        TX
# 23        CA
# 24        CA
# 25        IL
# 26        NY
# 27        PA
# 28        FL
# 29        MN
#         ...
# 42508     NY
# 42509     NJ
# 42510     FL
# 42511     GA
# 42512     CT
# 42513     CT
# 42514     NJ
# 42515     TX
# 42516     NJ
# 42517     MO
# 42518     NJ
# 42519     LA
# 42520     OH
# 42521     NJ
# 42522     CO
# 42523     NY
# 42524     GA
# 42525     MA
# 42526     CT
# 42527     KS
# 42528     MA
# 42529     FL
# 42530     CT
# 42531     NY
# 42532     MA
# 42533     NY
# 42534     NY
# 42535     CT
# 42536    NaN
# 42537    NaN
# Name: addr_state, Length: 42538, dtype: object

# %%
unq_state = unq_state[0:50]

# %%
state
# Out:
# 0         AZ
# 1         GA
# 2         IL
# 3         CA
# 4         OR
# 5         AZ
# 6         NC
# 7         CA
# 8         CA
# 9         TX
# 10        AZ
# 11        CA
# 12        VA
# 13        IL
# 14        CA
# 15        MO
# 16        CA
# 17        CT
# 18        UT
# 19        CA
# 20        TX
# 21        FL
# 22        TX
# 23        CA
# 24        CA
# 25        IL
# 26        NY
# 27        PA
# 28        FL
# 29        MN
#         ...
# 42508     NY
# 42509     NJ
# 42510     FL
# 42511     GA
# 42512     CT
# 42513     CT
# 42514     NJ
# 42515     TX
# 42516     NJ
# 42517     MO
# 42518     NJ
# 42519     LA
# 42520     OH
# 42521     NJ
# 42522     CO
# 42523     NY
# 42524     GA
# 42525     MA
# 42526     CT
# 42527     KS
# 42528     MA
# 42529     FL
# 42530     CT
# 42531     NY
# 42532     MA
# 42533     NY
# 42534     NY
# 42535     CT
# 42536    NaN
# 42537    NaN
# Name: addr_state, Length: 42538, dtype: object

# %%
import json

arr = []
for x in unq_state:
    if len(state[state==x]) >= 100:
#         print(x, ' - ', len(state[state==x]))
        m =numpy.mean(random.sample(list(data[data["addr_state"] == x]["loan_amnt"]), 50))
        arr.append({ "state": x, "avg": m })



# arr.sort(key=lambda x: x.avg)
arr = sorted(arr, key=lambda a: a['avg'])
print(json.dumps(arr))
# Out:
# [{"state": "RI", "avg": 8905.5}, {"state": "NM", "avg": 8981.0}, {"state": "WA", "avg": 9583.0}, {"state": "VA", "avg": 9680.0}, {"state": "FL", "avg": 9711.5}, {"state": "CT", "avg": 9716.0}, {"state": "HI", "avg": 9742.5}, {"state": "CO", "avg": 9957.5}, {"state": "WV", "avg": 10091.0}, {"state": "GA", "avg": 10343.0}, {"state": "WI", "avg": 10422.5}, {"state": "DE", "avg": 10505.0}, {"state": "OR", "avg": 10605.0}, {"state": "PA", "avg": 10609.5}, {"state": "AR", "avg": 10847.0}, {"state": "LA", "avg": 10934.0}, {"state": "AL", "avg": 10948.0}, {"state": "NV", "avg": 11184.0}, {"state": "TX", "avg": 11187.5}, {"state": "MN", "avg": 11210.0}, {"state": "OH", "avg": 11259.5}, {"state": "AZ", "avg": 11272.5}, {"state": "CA", "avg": 11382.0}, {"state": "MI", "avg": 11386.0}, {"state": "NJ", "avg": 11550.0}, {"state": "MO", "avg": 11572.5}, {"state": "SC", "avg": 11619.5}, {"state": "DC", "avg": 11660.0}, {"state": "KS", "avg": 11756.0}, {"state": "MA", "avg": 11822.5}, {"state": "NY",
# ...

# %%
state[state=="NY"]
# Out:
# 26       NY
# 30       NY
# 47       NY
# 74       NY
# 80       NY
# 82       NY
# 92       NY
# 103      NY
# 122      NY
# 163      NY
# 174      NY
# 178      NY
# 192      NY
# 195      NY
# 197      NY
# 229      NY
# 239      NY
# 242      NY
# 246      NY
# 277      NY
# 291      NY
# 297      NY
# 298      NY
# 305      NY
# 314      NY
# 315      NY
# 327      NY
# 334      NY
# 337      NY
# 346      NY
#          ..
# 42362    NY
# 42373    NY
# 42376    NY
# 42380    NY
# 42381    NY
# 42390    NY
# 42402    NY
# 42413    NY
# 42415    NY
# 42428    NY
# 42429    NY
# 42433    NY
# 42439    NY
# 42442    NY
# 42445    NY
# 42450    NY
# 42451    NY
# 42471    NY
# 42473    NY
# 42479    NY
# 42481    NY
# 42490    NY
# 42491    NY
# 42495    NY
# 42500    NY
# 42508    NY
# 42523    NY
# 42531    NY
# 42533    NY
# 42534    NY
# Name: addr_state, Length: 4065, dtype: object

# %%
numpy.mean(random.sample(list(data[data["addr_state"] == "CT"]["loan_amnt"]), 50))
# Out:
# 13326.0
